# %% [markdown]
# Pandas - Cleaning Empty Cells
#
# Empty Cells can ptoentially give you a wring result when you analyze data.
#
# Remove Rows
#
# One way to deal with empty cells is to remove rows that contain empty cells.
#
# This si usually OK, since data sets can be very big, and removing a few rows will not have big impact on the result.

# %%
import pandas as pd # pyright: ignore[reportMissingModuleSource]

df = pd.read_csv('calories.csv') #calories.csv the file with datas

new_df = df.dropna() #dropna() will return a new DataFrame, and will not change the original 

df.dropna(inplace = True) # if you want to change the original DataFrame

print(new_df.to_string())
# Out:
#                                Food    Measure  Weight (g)  kCal  Fat (g)  Carbo(g)  Protein (g)
# 0     1000 Island,Salad Drsng,Local     1 Tbsp       15.00    25        2         2            0
# 1     1000 Island,Salad Drsng,Reglr     1 Tbsp       16.00    60        6         2            0
# 2         40% Bran Flakes,Kellogg's       1 oz       28.35    90        1        22            4
# 3              40% Bran Flakes,Post       1 oz       28.35    90        0        22            3
# 4        Alfalfa Seeds,Sprouted,Raw      1 Cup       33.00    10        0         1            1
# 5                   All-Bran Cereal       1 oz       28.35    70        1        21            4
# 6                  Almonds,Slivered      1 Cup      135.00   795       70        28           27
# 7                     Almonds,Whole       1 oz       28.35   165       15         6            6
# 8           Angelfood Cake,From Mix     1 Cake      635.00  1510        2       342           38
# ...

# %% [markdown]
# Replace Only For Specified Columns
#
# The example above replaces all empty cells in the whole Data Frame.
#
# To only replace empty values for one column, specify the column name for the DataFrame:

# %%
import pandas as pd

df = pd.read_csv('calories.csv')

df.fillna({"Calories": 130}, inplace = True)

# %% [markdown]
# Replace Using Mean, Median, or Mode
#
# A common way to replace empty cells, is to calculate the mean, median or mode value of the column.
#
# Pnadas uses the mean() median() and mode() methods to calculate respective values for a specified column:

# %%
df = pd.read_csv('calories.csv')

x = df["Weight (g)"].mean()

a = df["Fat (g)"].median()

b = df["Carbo(g)"].mode()[0] 

# df.fillna({"Calories": x}, inplace = True)

print("the average wirght is ", x)

print("median fat mass ", a)

print("mode carb", b)
# Out:
# the average wirght is  149.53546874999998
# median fat mass  2.0
# mode carb 0

# %% [markdown]
# Pandas - Cleaning Data of Wrong Format
#
# Data of Wrong Format
#
# Cells with data of wrong format can make it difficult, or even impossible, to analyze data.
#
# To fix it, you have two options: remove the rows, convert all cells in the columns into the same format

# %%
df = pd.read_csv('calories.csv')

df['Date'] = pd.to_datetime(df['Date'], format='mixed')

# %% [markdown]
# Wrong Data
#
# "Wrong data" does not have to be "empty cells" or "wrong format", it can just be wrong, like if someonw registered "199" instead of "1.99".
#
# Sometimes you can spot wrong data by looking at the data set, because you have an expectation of what it should be.
#
# If you take a look at our data set, you can see that in row 7, the durtaion is 450, but for all the other rows the duration is between 30 and 60.
#
# It doesn't have to be wrong, but taking in consideration that this is the data set of someone's workout sessions, we conclude with the fact that this person did not workout in 450 min
#
#
# Replacing Value

# %%
# Where 7 is row num and "Duration" is the column name
df.loc[7, 'Duration'] = 45


#Loop through each row to find the wrong value and replace with 120 
for x in df.index:
    if df.loc[x, "Duration"] > 120:
        df.loc[x, "Duration"] = 120

# %% [markdown]
# Removing Rows
#
# Another way of handling wrong data is to reomve the rows that contains wrong data.
#
# This is way you do not have to find out what to replace them with, and there is a good chance you do not need them to do your analyses

# %%
for x in df.index:
    if df.loc[x, "Duration"] >120:
        df.drop(x, inplace=True)

# %% [markdown]
# Removing Duplicates
#
# Discovering Duplicates
#
# Duplicate rows are rows that have been registered more than one time.
#
# By taking a look at our test data set, we an assume that row 11 and 12 are duplicates.
#
# To discover duplicates, we can use duplicated() method.
#
# The duplicated() method returns a Boolean val for each row

# %%
print (df.duplicated())

#To remove duplicates, use the drop_duplicates() method 

df.drop_duplicates(inplace = True)
