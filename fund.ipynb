# %% [markdown]
# This is Fundametals

# %%
import pandas as pd

df = pd.read_csv("calories.csv")

# %%
print(df.info())

#top 5 el
df.head()

#bottom 5 el 
df.tail
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 960 entries, 0 to 959
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Food         960 non-null    object
#  1   Measure      960 non-null    object
#  2   Weight (g)   960 non-null    float64
#  3   kCal         960 non-null    int64
#  4   Fat (g)      960 non-null    int64
#  5   Carbo(g)     960 non-null    int64
#  6   Protein (g)  960 non-null    int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 52.6+ KB
# None
# <bound method NDFrame.tail of                                Food  Measure  Weight (g)  kCal  Fat (g)  \
# 0     1000 Island,Salad Drsng,Local   1 Tbsp       15.00    25        2
# 1     1000 Island,Salad Drsng,Reglr   1 Tbsp       16.00    60        6
# 2         40% Bran Flakes,Kellogg's     1 oz       28.35    90        1
# 3              40% Bran Flakes,Post     1 oz       28.35    90        0
# ...

# %%
#statistic
df.describe()
# Out:
#         Weight (g)         kCal    Fat (g)    Carbo(g)  Protein (g)
# count   960.000000   960.000000  960.00000  960.000000   960.000000
# mean    149.535469   270.585417   12.50625   34.025000     7.236458
# std     175.957583   543.182724   33.16150   78.537767    10.127206
# min       0.400000     0.000000    0.00000    0.000000     0.000000
# 25%      32.750000    65.000000    0.00000    3.000000     1.000000
# 50%     113.500000   125.000000    2.00000   14.000000     3.000000
# 75%     218.000000   230.000000   10.00000   31.000000     8.000000
# max    1542.000000  6175.000000  328.00000  783.000000    74.000000

# %%
df.columns
# Out:
# Index(['Food', 'Measure', 'Weight (g)', 'kCal', 'Fat (g)', 'Carbo(g)',
#        'Protein (g)'],
#       dtype='object')

# %%
df["Measure"]
# Out:
# 0       1 Tbsp
# 1       1 Tbsp
# 2         1 oz
# 3         1 oz
# 4        1 Cup
#         ...
# 955    1 Piece
# 956       8 oz
# 957       8 oz
# 958       8 oz
# 959       8 oz
# Name: Measure, Length: 960, dtype: object

# %%
# legth of the data frame
len(df)
# Out:
# 960

# %%
# unique vals 
set(df["Measure"])
# Out:
# {'1 Apple',
#  '1 Artchk',
#  '1 Avocdo',
#  '1 Bagel',
#  '1 Banana',
#  '1 Biscut',
#  '1 Browne',
#  '1 Cake',
#  '1 Carrot',
#  '1 Crackr',
#  '1 Crosst',
#  '1 Cu In',
#  '1 Cup',
#  '1 Cupcak',
#  '1 Donut',
#  '1 Ear',
#  '1 Egg',
#  '1 Enchld',
#  '1 Envelp',
#  '1 Envlpe',
#  '1 Fillet',
#  '1 Frank',
#  '1 Half',
#  '1 Head',
#  '1 Kiwi',
#  '1 Leaf',
#  '1 Lemon',
#  '1 Link',
#  '1 Liver',
#  '1 Loaf',
#  '1 Mango',
#  '1 Muffin',
#  '1 Nectrn',
#  '1 Orange',
#  '1 Oyster',
#  '1 Packet',
#  '1 Pancak',
#  '1 Pastry',
#  '1 Pat',
#  '1 Patty',
#  '1 Peach',
#  '1 Pear',
#  '1 Pepper',
#  '1 Pickle',
#  '1 Pie',
#  '1 Piece',
#  '1 Pita',
#  '1 Pkg',
#  '1 Pkt',
#  '1 Plantn',
#  '1 Plum',
#  '1 Popcle',
#  '1 Potato',
#  '1 Pretz',
#  '1 Ring',
#  '1 Roll',
#  '1 Sandwh',
#  '1 Sausag',
#  '1 Servng',
#  '1 Shell',
#  '1 Slice',
#  '1 Spear',
#  '1 Stalk',
#  '1 Stick',
#  '1 Taco',
#  '1 Tangrn',
#  '1 Tbsp',
#  '1 Tomato',
#  '1 Tortla',
#  '1 Tsp',
#  '1 Waffle',
# ...
